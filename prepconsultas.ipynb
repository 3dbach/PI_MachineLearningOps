# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
pd.options.display.max_columns = None

# %% [markdown]
# * DATRAFRAME NUMERO 1: STEAM GAMES

# %%
df1 = pd.read_csv('steam_games.csv')
df1
# Out:
#               publisher                                             genres
# 0             Kotoshiro  ['Action', 'Casual', 'Indie', 'Simulation', 'S...  \
# 1      Making Fun, Inc.       ['Free to Play', 'Indie', 'RPG', 'Strategy']
# 2          Poolians.com  ['Casual', 'Free to Play', 'Indie', 'Simulatio...
# 3                  彼岸领域                  ['Action', 'Adventure', 'Casual']
# 4                   NaN                                                NaN
# ...                 ...                                                ...
# 32130   Ghost_RUS Games      ['Casual', 'Indie', 'Simulation', 'Strategy']
# 32131            Sacada                    ['Casual', 'Indie', 'Strategy']
# 32132      Laush Studio                  ['Indie', 'Racing', 'Simulation']
# 32133          SIXNAILS                                ['Casual', 'Indie']
# 32134               NaN                                                NaN
#
#                        app_name                     title
# ...

# %%
#df1 = df1.sort_values(by='id')
#df1.head()

# %%
#registro2=df1.iloc[2]
#print(registro2)

# %%
#registro3=df1.loc[2,'url']
#print(registro3)

# %% [markdown]
# * DATAFRAME NUMERO 2: REVIEWS DE USUARIO

# %%
df2 = pd.read_csv('user_reviews.csv')
df2
# Out:
#                                   funny                     posted
# 0                                   NaN   Posted November 5, 2011.  \
# 1                                   NaN      Posted July 15, 2011.
# 2                                   NaN     Posted April 21, 2011.
# 3                                   NaN      Posted June 24, 2014.
# 4                                   NaN  Posted September 8, 2013.
# ...                                 ...                        ...
# 59300                               NaN            Posted July 10.
# 59301                               NaN             Posted July 8.
# 59302  1 person found this review funny             Posted July 3.
# 59303                               NaN            Posted July 20.
# 59304                               NaN             Posted July 2.
#
#       last_edited  item_id                                          helpful
# 0             NaN     1250                                   No ratings yet  \
# ...

# %% [markdown]
# * DATAFRAME NUMERO 3: ITEMS

# %%
df3 = pd.read_csv('items_completo.csv')
df3
# Out:
#                    user_id  items_count           steam_id
# 0        76561197970982479          277  76561197970982479  \
# 1        76561197970982479          277  76561197970982479
# 2        76561197970982479          277  76561197970982479
# 3        76561197970982479          277  76561197970982479
# 4        76561197970982479          277  76561197970982479
# ...                    ...          ...                ...
# 5170010  76561198329548331            7  76561198329548331
# 5170011  76561198329548331            7  76561198329548331
# 5170012  76561198329548331            7  76561198329548331
# 5170013  76561198329548331            7  76561198329548331
# 5170014  edward_tremethick            0  76561198331598578
#
#                                                   user_url   item_id
# 0        http://steamcommunity.com/profiles/76561197970...      10.0  \
# 1        http://steamcommunity.com/profiles/76561197970...      20.0
# ...

# %%
#registro=df3.loc[2,'user_url']
#print(registro)
# Out:
# http://steamcommunity.com/id/evcentric

# %%
# Tienes tu primer merge:
merged_df = pd.merge(df1, df2, left_on='id', right_on='item_id', how='outer')

# %%
merged_df
# Out:
#               publisher                                             genres
# 0             Kotoshiro  ['Action', 'Casual', 'Indie', 'Simulation', 'S...  \
# 1      Making Fun, Inc.       ['Free to Play', 'Indie', 'RPG', 'Strategy']
# 2          Poolians.com  ['Casual', 'Free to Play', 'Indie', 'Simulatio...
# 3                  彼岸领域                  ['Action', 'Adventure', 'Casual']
# 4                   NaN                                                NaN
# ...                 ...                                                ...
# 88240               NaN                                                NaN
# 88241               NaN                                                NaN
# 88242               NaN                                                NaN
# 88243               NaN                                                NaN
# 88244               NaN                                                NaN
#
#                       app_name                    title
# ...

# %%
# Ahora, añade el tercer merge usando el DataFrame resultante (merged_df) y df3:
merged_123 = pd.merge(merged_df, df3, left_on='id', right_on='item_id', how='outer', suffixes=('', '_df3'))
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# c:\Users\ag_om\OneDrive\HENRY\PROYECTO 1\PI_ML_OPS-FT\prepconsultas.ipynb Celda 16 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/ag_om/OneDrive/HENRY/PROYECTO%201/PI_ML_OPS-FT/prepconsultas.ipynb#X32sZmlsZQ%3D%3D?line=0'>1</a> # Ahora, añade el tercer merge usando el DataFrame resultante (merged_df) y df3:
# ----> <a href='vscode-notebook-cell:/c%3A/Users/ag_om/OneDrive/HENRY/PROYECTO%201/PI_ML_OPS-FT/prepconsultas.ipynb#X32sZmlsZQ%3D%3D?line=1'>2</a> merged_123 = pd.merge(merged_df, df3, left_on='id', right_on='item_id', how='outer', suffixes=('', '_df3'))
#
# File c:\Users\ag_om\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\reshape\merge.py:158, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
# ...

# %%
# Mostrando las primeras filas del DataFrame combinado para inspeccionar el resultado:
merged_123_head = merged_123.head()
merged_123_head
